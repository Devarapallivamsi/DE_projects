-- %%
%sql
CREATE OR REFRESH LIVE TABLE diagnostic_mapping
COMMENT "Bronze table for the diagnosis mapping file"
TBLPROPERTIES ("quality" = "bronze")
AS
SELECT *
FROM spark_workspace.default.src_raw_diag_map
-- Out:
-- <html>
--   <style>
-- <style>
--       html {
--         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
--         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
--         Noto Color Emoji,FontAwesome;
--         font-size: 13;
--       }
--
--       .ansiout {
--         padding-bottom: 8px;
--       }
--
--       .createPipeline {
--         background-color: rgb(34, 114, 180);
--         color: white;
--         text-decoration: none;
--         padding: 4px 12px;
--         border-radius: 4px;
--         display: inline-block;
--       }
--
--       .createPipeline:hover {
--         background-color: #195487;
--       }
--
--       .tag {
--         border: none;
--         color: rgb(31, 39, 45);
--         padding: 2px 4px;
--         font-weight: 600;
--         background-color: rgba(93, 114, 131, 0.08);
--         border-radius: 4px;
--         margin-right: 0;
--         display: inline-block;
--         cursor: default;
--       }
--
--       table {
--         border-collapse: collapse;
--         font-size: 13px;
--       }
--
--       th {
--         text-align: left;
--         background-color: #F2F5F7;
--         padding-left: 8px;
--         padding-right: 8px;
--       }
--
--       tr {
--         border-bottom: solid;
--         border-bottom-color: #CDDAE5;
--         border-bottom-width: 1px;
--       }
--
--       td {
--         padding-left: 8px;
--         padding-right: 8px;
--       }
--
--       .dlt-label {
--         font-weight: bold;
--       }
--
--       ul {
--         list-style: circle;
--         padding-inline-start: 12px;
--       }
--
--       li {
--         padding-bottom: 4px;
--       }
-- </style></style>
--
-- <div class="ansiout">
-- <span class='tag'>diagnostic_mapping</span> is defined as a
-- <span class="dlt-label">Delta Live Tables</span> dataset
--  with schema:
-- </div>
--
--
-- <div class="ansiout">
--    <table>
--      <tbody>
--        <tr>
--          <th>Name</th>
--          <th>Type</th>
--        </tr>
--
-- <tr>
--    <td>diagnosis_code</td>
--    <td>string</td>
-- </tr>
--
-- <tr>
--    <td>diagnosis_description</td>
--    <td>string</td>
-- </tr>
--      </tbody>
--    </table>
-- </div>
--
--   <div class ="ansiout">
--     To populate your table you must either:
--     <ul>
--       <li>
--         Run an existing pipeline using the
--         <span class="dlt-label">Delta Live Tables</span> menu
--       </li>
--       <li>
--         Create a new pipeline: <a class='createPipeline' href="?o=33766716428955#joblist/pipelines/create?initialSource=%2FUsers%2Fgcpvamsi123%40gmail.com%2FDefine_DLT_workflow&redirectNotebookId=1908064063703484">Create Pipeline</a>
--       </li>
--     </ul>
--   <div>
-- </html>

-- %%
%sql
CREATE OR REFRESH STREAMING TABLE daily_patients
COMMENT "Bronze table for daily patient data"
TBLPROPERTIES ("quality" = "bronze")
AS
SELECT *
FROM STREAM(spark_workspace.default.src_daily_pat_data)
-- Out:
-- <html>
--   <style>
-- <style>
--       html {
--         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
--         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
--         Noto Color Emoji,FontAwesome;
--         font-size: 13;
--       }
--
--       .ansiout {
--         padding-bottom: 8px;
--       }
--
--       .createPipeline {
--         background-color: rgb(34, 114, 180);
--         color: white;
--         text-decoration: none;
--         padding: 4px 12px;
--         border-radius: 4px;
--         display: inline-block;
--       }
--
--       .createPipeline:hover {
--         background-color: #195487;
--       }
--
--       .tag {
--         border: none;
--         color: rgb(31, 39, 45);
--         padding: 2px 4px;
--         font-weight: 600;
--         background-color: rgba(93, 114, 131, 0.08);
--         border-radius: 4px;
--         margin-right: 0;
--         display: inline-block;
--         cursor: default;
--       }
--
--       table {
--         border-collapse: collapse;
--         font-size: 13px;
--       }
--
--       th {
--         text-align: left;
--         background-color: #F2F5F7;
--         padding-left: 8px;
--         padding-right: 8px;
--       }
--
--       tr {
--         border-bottom: solid;
--         border-bottom-color: #CDDAE5;
--         border-bottom-width: 1px;
--       }
--
--       td {
--         padding-left: 8px;
--         padding-right: 8px;
--       }
--
--       .dlt-label {
--         font-weight: bold;
--       }
--
--       ul {
--         list-style: circle;
--         padding-inline-start: 12px;
--       }
--
--       li {
--         padding-bottom: 4px;
--       }
-- </style></style>
--
-- <div class="ansiout">
-- <span class='tag'>daily_patients</span> is defined as a
-- <span class="dlt-label">Delta Live Tables</span> dataset
--  with schema:
-- </div>
--
--
-- <div class="ansiout">
--    <table>
--      <tbody>
--        <tr>
--          <th>Name</th>
--          <th>Type</th>
--        </tr>
--
-- <tr>
--    <td>patient_id</td>
--    <td>string</td>
-- </tr>
--
-- <tr>
--    <td>name</td>
--    <td>string</td>
-- </tr>
--
-- <tr>
--    <td>age</td>
--    <td>int</td>
-- </tr>
--
-- <tr>
--    <td>gender</td>
--    <td>string</td>
-- </tr>
--
-- <tr>
--    <td>address</td>
--    <td>string</td>
-- </tr>
--
-- <tr>
--    <td>contact_number</td>
--    <td>string</td>
-- </tr>
--
-- <tr>
--    <td>admission_date</td>
--    <td>date</td>
-- </tr>
--
-- <tr>
--    <td>diagnosis_code</td>
--    <td>string</td>
-- </tr>
--      </tbody>
--    </table>
-- </div>
--
--   <div class ="ansiout">
--     To populate your table you must either:
--     <ul>
--       <li>
--         Run an existing pipeline using the
--         <span class="dlt-label">Delta Live Tables</span> menu
--       </li>
--       <li>
--         Create a new pipeline: <a class='createPipeline' href="?o=33766716428955#joblist/pipelines/create?initialSource=%2FUsers%2Fgcpvamsi123%40gmail.com%2FDefine_DLT_workflow&redirectNotebookId=1908064063703484">Create Pipeline</a>
--       </li>
--     </ul>
--   <div>
-- </html>

-- %%
%sql
CREATE OR REFRESH STREAMING TABLE processed_patient_data(CONSTRAINT valid_data EXPECT (patient_id IS NOT NULL and `name` IS NOT NULL and age IS NOT NULL and gender IS NOT NULL and `address` IS NOT NULL and contact_number IS NOT NULL and admission_date IS NOT NULL) ON VIOLATION DROP ROW)
COMMENT "Silver table with newly joined data from bronze tables and data quality constraints"
TBLPROPERTIES ("quality" = "silver")
AS
SELECT
    p.patient_id,
    p.name,
    p.age,
    p.gender,
    p.address,
    p.contact_number,
    p.admission_date,
    m.diagnosis_description
FROM STREAM(live.daily_patients) p
LEFT JOIN live.diagnostic_mapping m
ON p.diagnosis_code = m.diagnosis_code;

-- %%
%sql
CREATE LIVE TABLE patient_statistics_by_diagnosis
COMMENT "Gold table with detailed patient statistics by diagnosis description"
TBLPROPERTIES ("quality" = "gold")
AS
SELECT
    diagnosis_description,
    COUNT(patient_id) AS patient_count,
    AVG(age) AS avg_age,
    COUNT(DISTINCT gender) AS unique_gender_count,
    MIN(age) AS min_age,
    MAX(age) AS max_age
FROM live.processed_patient_data
GROUP BY diagnosis_description;
